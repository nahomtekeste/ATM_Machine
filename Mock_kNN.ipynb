# %% [markdown]
# <a href="https://colab.research.google.com/github/nahomtekeste/ATM_Machine/blob/main/Mock_kNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # kNN Clssifier
#
# In this task, kNN will be used to classify the Wine
# dataset.

# %% [markdown]
# 1.   Mount your google drive and change workingList item
# directory

# %%
# Code to mount google drive and change working directory
from google.colab import drive
drive.mount('/content/drive')
# %ls
# %cd drive/
# %ls
# %cd My\ Drive
# %ls
# %cd data
# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  cardata.csv    diabetes_with_head.csv   Mock_kNN.ipynb  'wine(1)(1).csv'
#  diabetes.csv   iris.csv                 voice.csv        wine.csv
# [Errno 2] No such file or directory: 'drive/'
# /content/drive/My Drive/data
#  cardata.csv    diabetes_with_head.csv   Mock_kNN.ipynb  'wine(1)(1).csv'
#  diabetes.csv   iris.csv                 voice.csv        wine.csv
# [Errno 2] No such file or directory: 'My Drive'
# /content/drive/My Drive/data
#  cardata.csv    diabetes_with_head.csv   Mock_kNN.ipynb  'wine(1)(1).csv'
#  diabetes.csv   iris.csv                 voice.csv        wine.csv
# [Errno 2] No such file or directory: 'data'
# /content/drive/My Drive/data
#  cardata.csv    diabetes_with_head.csv   Mock_kNN.ipynb  'wine(1)(1).csv'
#  diabetes.csv   iris.csv                 voice.csv        wine.csv

# %% [markdown]
# 2.   Import the required libraies
#
# > some libraries have beem omported
#
# > add the libries you may need in the follwoing code cell

# %%
# code to import the libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# 3. Import the dataset and explore the dataset
#
# > Add the code to import the dataset "**wine.csv**" and display the top 5 rows in the dataset in the code cell below and run it

# %%
# add the code to import the wine daatset

import pandas as pd

df = pd.read_csv('wine.csv')
print(df.shape)



# add the code to display the top 5 rows in the wine dataset

print(df.head(5))
# Out:
# (178, 14)
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %% [markdown]
# 4. Check the duplicate data

# %%
# enter the code to check rows containing duplicate data below
duplicae_rows_df = df[df.duplicated()]
print("number of duplicate rows:", duplicae_rows_df.shape)


# if needed, enter the code to deal with the duplicated data
df = df.drop_duplicates()
df.count()
# Out:
# number of duplicate rows: (0, 14)
# Class                           178
# Alcohol                         178
# Malic acid                      178
# Ash                             178
# Alcalinity of ash               178
# Magnesium                       178
# Total phenols                   178
# Flavanoids                      178
# Nonflavanoid phenols            178
# Proanthocyanins                 178
# Color intensity                 178
# Hue                             178
# OD280/OD315 of diluted wines    178
# Proline                         178
# dtype: int64

# %% [markdown]
# 5. Plot histograms of numeric variables

# %%
# enter the code to plot histogram of 'Alcohol' below and run it
plt.hist(df['Alcohol'], bins=20)
plt.title('Alcohol')
plt.ylabel('Frequency')
plt.xlabel('Alcohol')
plt.show()

# %% [markdown]
# 6. Specify the input variables and the target variable

# %%
# enter the code to specify the input variables and the target variable below and run it

x = df.drop('Class', axis=1)
y = df['Class']
x.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline
# ...

# %% [markdown]
# 7. Split the dataset into two pieces: training set and testing set

# %%
# enter the code to split dataset into training set and testing set below and run it
# Split the dataset into two pieces: training set and testing set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

print(x_train.shape)
# Out:
# (142, 13)

# %% [markdown]
# 8. Build the kNN clssifier

# %%
# enter the code to create a kNN classifier and fit the classifier

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)
